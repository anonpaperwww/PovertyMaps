# %%
# %load_ext autoreload
# %autoreload 2
import handlers as supmat

# %%
supmat.sns_reset()
supmat.sns_paper_style()
supmat.set_latex()

# %%
ROOT = '../data'
COUNTRIES = ['Sierra Leone','Uganda']
YEARS = {'Sierra Leone':[2016,2019], 'Uganda':[2016,2018]}
RESULTS = 'results'
PLOTS = 'supmat-plots'

# %% [markdown]
# # Ground-truth

# %% [markdown]
# ## Figures

# %%
supmat.plot_wealth_distribution_per_year(ROOT, COUNTRIES, PLOTS)
# Out:
# [INFO] ../data/Sierra Leone/results/features/clusters/DHS2008_DHS2013_DHS2019_MIS2016_iwi_cluster.csv loaded.
# [INFO] ../data/Uganda/results/features/clusters/DHS2006_DHS2011_DHS2016_MIS2009_MIS2014_MIS2018_iwi_cluster.csv loaded.
# supmat-plots/sm_wealth_distribution_per_year.pdf saved!

# %%
df_gt = supmat.load_gt_data(ROOT, COUNTRIES)
df_gt.sample(5)
# Out:
# [INFO] ../data/Sierra Leone/results/features/clusters/DHS2019_MIS2016_iwi_cluster.csv loaded.
# [INFO] ../data/Uganda/results/features/clusters/DHS2016_MIS2018_iwi_cluster.csv loaded.
# [INFO] 1894 records, 15 columns.
#                   gtID ccode dsource  year  cluster        lon       lat  \
# 426   SL20190000000092    SL     DHS  2019       92 -11.425239  7.223758
# 557   SL20190000000228    SL     DHS  2019      228 -11.664592  7.711939
# 1673  UG20180000000096    UG     MIS  2018       96  34.100597  0.995491
# 1207  UG20160000000321    UG     DHS  2016      321  34.848012  2.572625
# 1147  UG20160000000261    UG     DHS  2016      261  34.156923  1.082406
#
#       rural  counts    mean_wi     std_wi mean_wi_bin   mean_wi_cat  \
# 426       1      24  12.393744   8.183843     [0, 25)          poor
# 557       1      23  22.448132   8.901827     [0, 25)          poor
# 1673      1      27  14.819667   9.502382     [0, 25)          poor
# 1207      1      27   2.352745   4.718971     [0, 25)          poor
# 1147      0      29  30.928667  14.446914    [25, 50)  lower_middle
#
#       mean_wi_cat_id   countryname
# 426                0  Sierra Leone
# 557                0  Sierra Leone
# 1673               0        Uganda
# 1207               0        Uganda
# 1147               1        Uganda

# %%
supmat.plot_map(df_gt, kind='wealth', output=PLOTS)
# Out:
# supmat-plots/sm_gt_maps_wealth.pdf saved!

# %%
supmat.plot_map(df_gt, kind='year', output=PLOTS)
# Out:
# supmat-plots/sm_gt_maps_year.pdf saved!

# %%
supmat.plot_map(df_gt, kind='settlement', output=PLOTS)
# Out:
# supmat-plots/sm_gt_maps_settlement.pdf saved!

# %%
supmat.plot_map(df_gt, kind='year_settlement', output=PLOTS)
# Out:
# supmat-plots/sm_gt_maps_year_settlement.pdf saved!

# %%
supmat.plot_correlation(df_gt, PLOTS)
# Out:
# supmat-plots/sm_gt_corr_mean_std.pdf saved!

# %%
supmat.plot_cells_reg(ROOT, COUNTRIES, PLOTS)
# Out:
# [INFO] shapes: cells 893  | clusters 893 | join 893
# [INFO] shapes: cells 1001  | clusters 1001 | join 1001
# supmat-plots/sm_gt_corr_cells_mean.pdf saved!

# %%
supmat.plot_data_augmentation(ROOT, COUNTRIES[1], prefix='Y2018-C5-U0', output=PLOTS) 
#COUNTRIES[1], prefix='Y2018-C5-U0'    
#COUNTRIES[0], prefix='Y2019-C81-U1'  
#COUNTRIES[0], prefix='Y2019-C41-U0'
# Out:
# [INFO] ../data/Uganda/results/staticmaps/clusters/Y2018-C5-U0-LA0.330685-LO32.562855-ZO16-SC1-640x640-satellite
# supmat-plots/sm_augmentation.pdf saved!

# %%
supmat.plot_distance_distribution_location_change(ROOT, COUNTRIES, PLOTS)
# Out:
# supmat-plots/sm_distance_reallocation.pdf saved!

# %% [markdown]
# ## Tables

# %%
supmat.record_per_year_and_country(df_gt)
# Out:
#        records
# ccode       SL   UG
# syear
# Newest     557  316
# Oldest     336  685

# %%
supmat.tbl_data_summary(root=ROOT, countries=COUNTRIES, years=YEARS, output=RESULTS)
# Out:
# [INFO] ../data/Sierra Leone/results/features/households/DHS2019_MIS2016_iwi_household.csv loaded!
# [INFO] ../data/Sierra Leone/results/features/clusters/DHS2019_MIS2016_iwi_cluster.csv loaded!
# [INFO] ../data/Sierra Leone/results/features/pplaces/PPLACES.csv loaded!
# [INFO] ../data/Sierra Leone/results/features/DHS2019_MIS2016_ruc_cluster_pplace_ids.csv loaded!
# [INFO] ../data/Uganda/results/features/households/DHS2016_MIS2018_iwi_household.csv loaded!
# [INFO] ../data/Uganda/results/features/clusters/DHS2016_MIS2018_iwi_cluster.csv loaded!
# [INFO] ../data/Uganda/results/features/pplaces/PPLACES.csv loaded!
# [INFO] ../data/Uganda/results/features/DHS2016_MIS2018_ruc_cluster_pplace_ids.csv loaded!
# country                  Sierra Leone       Uganda
# years                       2016,2019    2016,2018
# households                      19975        27798
# clusters                          893         1001
# urban                       308 (34%)    242 (24%)
# rural                       585 (66%)    759 (76%)
# IWI mean min                      4.2          2.0
# IWI mean max                     72.7         82.9
# IWI mean mean                    26.2         24.8
# IWI mean std.dev.                15.6         14.9
# IWI std min                       3.8          3.9
# IWI std max                      22.8         22.4
# IWI std mean                     10.4         11.4
# IWI std std.dev.                  3.5          3.4
# pearson                   0.71 (****)  0.64 (****)
# gini                             0.32         0.31
# WB gini index             35.7 (2018)  42.7 (2019)
# WB gdp per capita (US $)     501, 522     733, 771
# WB growth anual (%)          6.1, 5.3     4.8, 6.3
# populated places                 9881        27791
# pplaces urban                366 (4%)     348 (1%)
# pplaces rural              9515 (96%)  27443 (99%)
# relocation                  705 (79%)    733 (73%)
# relocation urban            120 (39%)     71 (29%)
# relocation rural           585 (100%)    662 (87%)

# %%
supmat.tbl_features_summary(root=ROOT, countries=COUNTRIES, years=YEARS, output=RESULTS)
# Out:
# country
# Sierra Leone    957
# Uganda          957
# dtype: int64
# country     Sierra Leone  Uganda
# source
# FBM                   37      37
# FBMV                  27      27
# GMSA                 784     784
# NTLL                  36      36
# OSM                   54      54
# cells                  9       9
# population             9       9
# settlement             1       1

# %% [markdown]
# # Performance

# %%
# df_dr = supmat.get_performance(root=ROOT, countries=COUNTRIES, output=RESULTS)
df_rs = supmat.get_residuals(root=ROOT, countries=COUNTRIES, output=RESULTS)
df_dr = supmat.get_performance_from_predictions(df_rs=df_rs, output=RESULTS)
df_gt = supmat.get_ground_truth(root=ROOT, countries=COUNTRIES, output=RESULTS)

# %% [markdown]
# ## Models and data sources

# %%
metric = 'r2'
supmat.tbl_performance_by_model_and_datasource(df_dr, metric=metric, output=RESULTS)
# Out:
#                                         r2_SL  r2_mean_SL  r2_std_SL  \
# model          De Mo Po Nl An In Im
# CB             y  y  y  y  y  y  -   0.559011    0.785811   0.332211
# CB$_w$         y  y  y  y  y  y  -   0.598889    0.807166   0.390612
# CNN            -  -  -  -  -  -  y   0.427236    0.672848   0.181624
# CNN$_a$        -  -  -  -  -  -  y   0.379723    0.643467   0.115980
# CNN$_a$+CB     y  y  y  y  y  y  y   0.557848    0.786088   0.329609
# CNN$_a$+CB$_w$ y  y  y  y  y  y  y   0.578661    0.791052   0.366270
# CNN+CB         y  y  y  y  y  y  y   0.558796    0.795817   0.321775
# CNN+CB$_w$     y  y  y  y  y  y  y   0.576516    0.796517   0.356515
# CB$_w$         y  -  -  -  -  -  -   0.287335    0.457404   0.117267
#                -  y  -  -  -  -  -   0.559454    0.778846   0.340062
#                   -  y  -  -  -  -   0.579644    0.794605   0.364683
#                      -  y  -  -  -   0.520041    0.724880   0.315202
#                         -  y  -  -   0.481217    0.721972   0.240463
#                            -  y  -   0.508628    0.740736   0.276520
#
#                                         r2_UG  r2_mean_UG  r2_std_UG
# model          De Mo Po Nl An In Im
# CB             y  y  y  y  y  y  -   0.545503    0.782945   0.308061
# CB$_w$         y  y  y  y  y  y  -   0.525573    0.773588   0.277558
# CNN            -  -  -  -  -  -  y   0.379029    0.638605   0.119452
# CNN$_a$        -  -  -  -  -  -  y   0.402659    0.643908   0.161410
# CNN$_a$+CB     y  y  y  y  y  y  y   0.542167    0.781720   0.302613
# CNN$_a$+CB$_w$ y  y  y  y  y  y  y   0.528919    0.778038   0.279799
# CNN+CB         y  y  y  y  y  y  y   0.500041    0.738407   0.261675
# CNN+CB$_w$     y  y  y  y  y  y  y   0.489319    0.729168   0.249469
# CB$_w$         y  -  -  -  -  -  -   0.227426    0.406531   0.048320
#                -  y  -  -  -  -  -   0.416594    0.692644   0.140544
#                   -  y  -  -  -  -   0.406218    0.621982   0.190453
#                      -  y  -  -  -   0.505656    0.752246   0.259067
#                         -  y  -  -   0.446452    0.685599   0.207305
#                            -  y  -   0.416579    0.629232   0.203925

# %% [markdown]
# ## Intersectionality

# %%
var = 'std'
n_classes = 5
class_type = 'quantiles'
evaluation = 'rmse'
supmat.tbl_intersectionality(df_rs, df_gt, n_classes=n_classes, class_type=class_type, var=var, evaluation=evaluation, output=None)
# Out:
# [INFO] quantiles are only measured on the mean wealth index. Using true_mean instead of true_std to create the quantiles.
# [INFO] quantiles are only measured on the mean wealth index. Using true_mean instead of true_std to create the quantiles.
#                               Q1_SL     Q2_SL     Q3_SL     Q4_SL     Q5_SL  \
# settlement model
# rural      CB              1.817523  1.908910  2.549777  3.655718  6.642005
#            CB$_w$          2.022062  1.906643  2.509885  3.644936  6.413048
#            CNN              1.83978  1.897439  2.630459  4.212016  7.011840
#            CNN$_a$         2.063435  1.870847  2.675992  3.936015  6.461481
#            CNN+CB          1.908966  1.958695  2.426099  3.868610  6.191237
#            CNN+CB$_w$      1.775761  1.852575  2.344410  3.830905  6.377916
#            CNN$_a$+CB       2.02413  1.807830  2.548226  3.719379  6.843165
#            CNN$_a$+CB$_w$   1.84428  1.812167  2.470079  3.625613  6.599772
# urban      CB                     -  6.275826  1.809115  3.738198  3.234827
#            CB$_w$                 -  4.083728  2.273107  3.796172  3.547907
#            CNN                    -  2.138459  2.225764  4.123311  4.008270
#            CNN$_a$                -  2.830634  2.243148  4.375489  4.341429
#            CNN+CB                 -  4.555815  2.142453  3.626892  3.424189
#            CNN+CB$_w$             -  4.192073  2.112001  3.600565  3.322918
#            CNN$_a$+CB             -  5.126934  1.806336  3.475044  3.370724
#            CNN$_a$+CB$_w$         -  5.110600  2.144226  3.381602  3.312480
#
#                               Q1_UG     Q2_UG     Q3_UG     Q4_UG     Q5_UG
# settlement model
# rural      CB              2.459630  2.217257  2.310733  3.547901  4.134399
#            CB$_w$          3.115597  2.184853  2.472940  3.660116  4.452535
#            CNN             3.275690  2.604121  2.527669  3.541177  4.843835
#            CNN$_a$         2.824091  2.236446  2.493378  3.891148  5.163012
#            CNN+CB          2.583438  2.336078  2.466822  3.633298  4.550849
#            CNN+CB$_w$      2.662185  2.318842  2.434976  3.680493  4.649976
#            CNN$_a$+CB      2.516189  2.234370  2.399955  3.580830  4.349839
#            CNN$_a$+CB$_w$  2.524047  2.243031  2.412418  3.689978  4.387581
# urban      CB              2.515257  2.787207  3.396754  3.796590  3.028961
#            CB$_w$          3.771073  3.483915  2.928551  3.815329  3.278435
#            CNN             3.883885  1.923414  1.928403  3.819473  3.452997
#            CNN$_a$         3.281245  2.585711  1.809170  4.191505  3.321273
#            CNN+CB          3.668274  2.881690  2.362713  3.746644  3.023598
#            CNN+CB$_w$      3.740742  2.112348  2.004333  3.846822  3.053441
#            CNN$_a$+CB      3.555628  2.468570  3.062779  3.685378  2.848030
#            CNN$_a$+CB$_w$  3.460160  2.501916  2.649731  3.758816  2.992651

# %%
var = 'mean'
n_classes = 5
class_type = 'class'
evaluation = 'recall'
supmat.tbl_intersectionality(df_rs, df_gt, n_classes=n_classes, class_type=class_type, var=var, evaluation=evaluation, output=RESULTS)
# Out:
# [INFO] Sierra Leone bins: [ -0.1  20.   40.   60.   80.  100. ]
# [INFO] Uganda bins: [ -0.1  20.   40.   60.   80.  100. ]
#                               Q1_SL     Q2_SL     Q3_SL     Q4_SL     Q1_UG  \
# settlement model
# rural      CB              0.908745  0.326316  0.400000         -  0.793333
#            CB$_w$           0.73384  0.428571  0.314286         -  0.765238
#            CNN             0.775665  0.484211  0.600000         -  0.540000
#            CNN$_a$         0.707224  0.494737  0.400000         -  0.543333
#            CNN+CB          0.878327  0.452632  0.600000         -  0.680000
#            CNN+CB$_w$      0.885932  0.484211  0.400000         -  0.696667
#            CNN$_a$+CB       0.86692  0.357895  0.400000         -  0.773333
#            CNN$_a$+CB$_w$  0.863118  0.357895  0.400000         -  0.780000
# urban      CB                     -  0.883117  0.666667  0.259259  0.500000
#            CB$_w$          0.285714  0.714286  0.635531  0.375661  0.469388
#            CNN                  1.0  0.493506  0.820513  0.148148  0.428571
#            CNN$_a$         0.666667  0.558442  0.666667  0.185185  0.428571
#            CNN+CB                 -  0.805195  0.743590  0.222222  0.357143
#            CNN+CB$_w$             -  0.740260  0.756410  0.259259  0.500000
#            CNN$_a$+CB             -  0.896104  0.641026  0.222222  0.357143
#            CNN$_a$+CB$_w$         -  0.896104  0.679487  0.333333  0.285714
#
#                               Q2_UG     Q3_UG     Q4_UG
# settlement model
# rural      CB              0.496644  0.444444         -
#            CB$_w$          0.413231  0.253968         -
#            CNN             0.644295  0.111111         -
#            CNN$_a$         0.597315  0.111111         -
#            CNN+CB          0.563758  0.111111         -
#            CNN+CB$_w$      0.570470  0.111111         -
#            CNN$_a$+CB      0.543624  0.111111         -
#            CNN$_a$+CB$_w$  0.536913  0.222222         -
# urban      CB              0.791667  0.756757       0.3
#            CB$_w$          0.532738  0.633205  0.314286
#            CNN             0.666667  0.554054         -
#            CNN$_a$         0.583333  0.554054      0.05
#            CNN+CB          0.625000  0.689189      0.15
#            CNN+CB$_w$      0.645833  0.702703       0.1
#            CNN$_a$+CB      0.729167  0.783784       0.1
#            CNN$_a$+CB$_w$  0.770833  0.824324      0.15

# %%
var = 'mean'
n_classes = 5
class_type = 'class'
evaluation = 'precision'
supmat.tbl_intersectionality(df_rs, df_gt, n_classes=n_classes, class_type=class_type, var=var, evaluation=evaluation, output=RESULTS)
# Out:
# [INFO] Sierra Leone bins: [ -0.1  20.   40.   60.   80.  100. ]
# [INFO] Uganda bins: [ -0.1  20.   40.   60.   80.  100. ]
#                               Q1_SL     Q2_SL     Q3_SL     Q4_SL     Q1_UG  \
# settlement model
# rural      CB              0.783607  0.543860  1.000000         -  0.765273
#            CB$_w$           0.77733  0.359848  0.611111         -  0.726492
#            CNN             0.806324  0.429907  0.750000         -  0.750000
#            CNN$_a$         0.791489  0.373016  0.666667         -  0.727679
#            CNN+CB           0.81338  0.558442  1.000000         -  0.758364
#            CNN+CB$_w$      0.820423  0.589744  1.000000         -  0.765568
#            CNN$_a$+CB      0.783505  0.478873  1.000000         -  0.773333
#            CNN$_a$+CB$_w$  0.782759  0.472222  1.000000         -  0.769737
# urban      CB                     -  0.772727  0.641975       0.5  0.777778
#            CB$_w$          0.081081  0.712963  0.622980  0.572581  0.356589
#            CNN               0.1875  0.730769  0.566372       1.0  0.428571
#            CNN$_a$         0.181818  0.651515  0.530612       0.5  0.375000
#            CNN+CB                 -  0.794872  0.630435       0.5  0.454545
#            CNN+CB$_w$             -  0.791667  0.614583  0.538462  0.538462
#            CNN$_a$+CB             -  0.775281  0.632911     0.375  0.454545
#            CNN$_a$+CB$_w$         -  0.766667  0.670886       0.6  0.500000
#
#                               Q2_UG     Q3_UG     Q4_UG
# settlement model
# rural      CB              0.524823  0.666667         -
#            CB$_w$          0.458511  0.301887         -
#            CNN             0.405063  0.200000         -
#            CNN$_a$         0.383621  0.500000         -
#            CNN+CB          0.449198  0.500000         -
#            CNN+CB$_w$      0.464481  0.500000         -
#            CNN$_a$+CB      0.515924  1.000000         -
#            CNN$_a$+CB$_w$  0.526316  1.000000         -
# urban      CB              0.678571  0.708861  0.461538
#            CB$_w$          0.537538  0.645669     0.352
#            CNN             0.484848  0.585714         -
#            CNN$_a$         0.451613  0.577465     0.125
#            CNN+CB          0.535714  0.645570  0.272727
#            CNN+CB$_w$      0.563636  0.650000  0.222222
#            CNN$_a$+CB      0.636364  0.698795      0.25
#            CNN$_a$+CB$_w$  0.637931  0.709302       0.6

# %% [markdown]
# ## Variability

# %%
supmat.plot_variability_full(df_rs, output=PLOTS)
# Out:
# [INFO] Sierra Leone Q-0.2: 13.05
# [INFO] Sierra Leone Q-0.4: 17.28
# [INFO] Sierra Leone Q-0.6: 25.23
# [INFO] Sierra Leone Q-0.8: 39.88
# [INFO] Sierra Leone Q-1.0: 71.94
# [INFO] Uganda Q-0.2: 14.07
# [INFO] Uganda Q-0.4: 18.05
# [INFO] Uganda Q-0.6: 23.27
# [INFO] Uganda Q-0.8: 34.44
# [INFO] Uganda Q-1.0: 82.90
# Goodness-of-fit (deg=2): rmse=2.02, r2=0.39 | Sierra Leone - ground-truth - rural
# Goodness-of-fit (deg=2): rmse=3.11, r2=0.19 | Sierra Leone - ground-truth - urban
# Goodness-of-fit (deg=2): rmse=0.58, r2=0.74 | Sierra Leone - CB - rural
# Goodness-of-fit (deg=2): rmse=1.21, r2=0.62 | Sierra Leone - CB - urban
# Goodness-of-fit (deg=2): rmse=0.38, r2=0.86 | Sierra Leone - CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=0.96, r2=0.72 | Sierra Leone - CB$_w$ - urban
# Goodness-of-fit (deg=2): rmse=0.62, r2=0.62 | Sierra Leone - CNN - rural
# Goodness-of-fit (deg=2): rmse=0.89, r2=0.85 | Sierra Leone - CNN - urban
# Goodness-of-fit (deg=2): rmse=0.47, r2=0.84 | Sierra Leone - CNN$_a$ - rural
# Goodness-of-fit (deg=2): rmse=0.78, r2=0.93 | Sierra Leone - CNN$_a$ - urban
# Goodness-of-fit (deg=2): rmse=0.63, r2=0.65 | Sierra Leone - CNN+CB - rural
# Goodness-of-fit (deg=2): rmse=1.19, r2=0.62 | Sierra Leone - CNN+CB - urban
# Goodness-of-fit (deg=2): rmse=0.56, r2=0.68 | Sierra Leone - CNN+CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=1.05, r2=0.68 | Sierra Leone - CNN+CB$_w$ - urban
# Goodness-of-fit (deg=2): rmse=0.60, r2=0.67 | Sierra Leone - CNN$_a$+CB - rural
# Goodness-of-fit (deg=2): rmse=1.21, r2=0.61 | Sierra Leone - CNN$_a$+CB - urban
# Goodness-of-fit (deg=2): rmse=0.54, r2=0.73 | Sierra Leone - CNN$_a$+CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=1.03, r2=0.67 | Sierra Leone - CNN$_a$+CB$_w$ - urban
# Goodness-of-fit (deg=2): rmse=1.91, r2=0.62 | Uganda - ground-truth - rural
# Goodness-of-fit (deg=2): rmse=2.97, r2=0.17 | Uganda - ground-truth - urban
# Goodness-of-fit (deg=2): rmse=0.55, r2=0.90 | Uganda - CB - rural
# Goodness-of-fit (deg=2): rmse=1.31, r2=0.53 | Uganda - CB - urban
# Goodness-of-fit (deg=2): rmse=0.70, r2=0.83 | Uganda - CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=1.36, r2=0.50 | Uganda - CB$_w$ - urban
# Goodness-of-fit (deg=2): rmse=0.90, r2=0.71 | Uganda - CNN - rural
# Goodness-of-fit (deg=2): rmse=1.43, r2=0.63 | Uganda - CNN - urban
# Goodness-of-fit (deg=2): rmse=0.74, r2=0.72 | Uganda - CNN$_a$ - rural
# Goodness-of-fit (deg=2): rmse=0.97, r2=0.80 | Uganda - CNN$_a$ - urban
# Goodness-of-fit (deg=2): rmse=0.70, r2=0.81 | Uganda - CNN+CB - rural
# Goodness-of-fit (deg=2): rmse=1.41, r2=0.38 | Uganda - CNN+CB - urban
# Goodness-of-fit (deg=2): rmse=0.77, r2=0.77 | Uganda - CNN+CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=1.48, r2=0.36 | Uganda - CNN+CB$_w$ - urban
# Goodness-of-fit (deg=2): rmse=0.54, r2=0.89 | Uganda - CNN$_a$+CB - rural
# Goodness-of-fit (deg=2): rmse=1.20, r2=0.52 | Uganda - CNN$_a$+CB - urban
# Goodness-of-fit (deg=2): rmse=0.61, r2=0.87 | Uganda - CNN$_a$+CB$_w$ - rural
# Goodness-of-fit (deg=2): rmse=1.21, r2=0.52 | Uganda - CNN$_a$+CB$_w$ - urban
# supmat-plots/sm_mean_vs_std.pdf saved!

# %% [markdown]
# ## Model transferability

# %%
metric = 'rmse'
supmat.tbl_cross_testing(df_dr, metric=metric, output=RESULTS)
# Out:
#                source_country   SL_rmse   UG_rmse  SL_rmse_mean_wi  \
# source_model
# CB               Sierra Leone  5.056993  6.150468         7.282021
# CB                     Uganda  5.343755  5.019768         7.836990
# CB$_w$           Sierra Leone  4.808886  6.071307         6.912095
# CB$_w$                 Uganda  5.440457  5.116864         7.877572
# CNN              Sierra Leone  6.070033  7.850307         9.003736
# CNN                    Uganda  7.996219  6.245794        12.609200
# CNN$_a$          Sierra Leone  6.316700  7.638323         9.378194
# CNN$_a$                Uganda  7.682201  6.172329        12.123833
# CNN+CB           Sierra Leone  4.987485  6.962239         7.119380
# CNN+CB                 Uganda  6.213369  5.416010         9.415890
# CNN+CB$_w$       Sierra Leone  4.941455  6.850466         7.102585
# CNN+CB$_w$             Uganda  6.234324  5.499443         9.414738
# CNN$_a$+CB       Sierra Leone  5.058776  6.452097         7.279647
# CNN$_a$+CB             Uganda  5.652223  5.035552         8.351945
# CNN$_a$+CB$_w$   Sierra Leone  4.974306  6.440587         7.188000
# CNN$_a$+CB$_w$         Uganda  5.624428  5.087024         8.319433
#
#                 UG_rmse_mean_wi  SL_rmse_std_wi  UG_rmse_std_wi
# source_model
# CB                     9.183721        2.831965        3.117215
# CB                     7.174337        2.850520        2.865199
# CB$_w$                 9.152054        2.705678        2.990559
# CB$_w$                 7.306871        3.003342        2.926857
# CNN                   12.353727        3.136330        3.346886
# CNN                    9.262150        3.383237        3.229438
# CNN$_a$               11.838678        3.255205        3.437967
# CNN$_a$                9.189562        3.240570        3.155096
# CNN+CB                10.777278        2.855590        3.147200
# CNN+CB                 7.872807        3.010848        2.959212
# CNN+CB$_w$            10.624630        2.780326        3.076302
# CNN+CB$_w$             8.014443        3.053909        2.984444
# CNN$_a$+CB             9.796011        2.837906        3.108184
# CNN$_a$+CB             7.194711        2.952500        2.876393
# CNN$_a$+CB$_w$         9.783147        2.760611        3.098026
# CNN$_a$+CB$_w$         7.250100        2.929423        2.923948

# %%
metric = 'r2'
supmat.tbl_cross_testing(df_dr, metric=metric, output=RESULTS)
# Out:
#                source_country     SL_r2     UG_r2  SL_r2_mean_wi  \
# source_model
# CB               Sierra Leone  0.559011  0.410322       0.785811
# CB                     Uganda  0.537482  0.545503       0.752247
# CB$_w$           Sierra Leone  0.598889  0.444480       0.807166
# CB$_w$                 Uganda  0.498313  0.525573       0.749302
# CNN              Sierra Leone  0.427236  0.205712       0.672848
# CNN                    Uganda  0.200621  0.379029       0.356085
# CNN$_a$          Sierra Leone  0.379723  0.205147       0.643467
# CNN$_a$                Uganda  0.265130  0.402659       0.404580
# CNN+CB           Sierra Leone  0.558796  0.335707       0.795817
# CNN+CB                 Uganda  0.443911  0.500041       0.642177
# CNN+CB$_w$       Sierra Leone  0.576516  0.362020       0.796517
# CNN+CB$_w$             Uganda  0.432996  0.489319       0.642188
# CNN$_a$+CB       Sierra Leone  0.557848  0.390446       0.786088
# CNN$_a$+CB             Uganda  0.496457  0.542167       0.718611
# CNN$_a$+CB$_w$   Sierra Leone  0.578661  0.393428       0.791052
# CNN$_a$+CB$_w$         Uganda  0.503044  0.528919       0.720804
#
#                 UG_r2_mean_wi  SL_r2_std_wi  UG_r2_std_wi
# source_model
# CB                   0.641980      0.332211      0.178664
# CB                   0.782945      0.322717      0.308061
# CB$_w$               0.644448      0.390612      0.244513
# CB$_w$               0.773588      0.247324      0.277558
# CNN                  0.356119      0.181624      0.055304
# CNN                  0.638605      0.045158      0.119452
# CNN$_a$              0.406900      0.115980      0.003395
# CNN$_a$              0.643908      0.125681      0.161410
# CNN+CB               0.506733      0.321775      0.164681
# CNN+CB               0.738407      0.245645      0.261675
# CNN+CB$_w$           0.521543      0.356515      0.202496
# CNN+CB$_w$           0.729168      0.223804      0.249469
# CNN$_a$+CB           0.595123      0.329609      0.185769
# CNN$_a$+CB           0.781720      0.274302      0.302613
# CNN$_a$+CB$_w$       0.596395      0.366270      0.190460
# CNN$_a$+CB$_w$       0.778038      0.285283      0.279799

# %% [markdown]
# ## Pre-processing

# %%
metric = 'nrmse'
kind='point' # strip, swarm, point, line, box, boxen, violin, bar
supmat.plot_performance(df_dr, metric=metric, kind=kind, output=PLOTS)
# Out:
# supmat-plots/sm_performance_nrmse.pdf saved!

# %%
metric = 'rmse'
message = f"The {'lower' if 'mse' in metric else 'larger'} the better"

# %%
kind='point' # strip, swarm, point, line, box, boxen, violin, bar
supmat.plot_performance(df_dr, metric=metric, kind=kind, output=PLOTS)
# Out:
# supmat-plots/sm_performance_rmse.pdf saved!

# %%
supmat.plot_performance(df_dr, metric=f'{metric}_mean_wi', kind=kind, output=PLOTS)
# Out:
# supmat-plots/sm_performance_rmse_mean_wi.pdf saved!

# %%
supmat.plot_performance(df_dr, metric=f'{metric}_std_wi', kind=kind, output=PLOTS)
# Out:
# supmat-plots/sm_performance_rmse_std_wi.pdf saved!
